# %%
import pandas as pd
df = pd.read_csv('retail_store_inventory.csv')

# %% [markdown]
# ## Handling the Missing Data
# ### Filling the categorical Columns using mode and filling the numeric columns using mean

# %%
df['Region'] = df['Region'].fillna(df['Region'].mode()[0])
df['Weather Condition'] = df['Weather Condition'].fillna(df['Weather Condition'].mode()[0])
df['Holiday/Promotion'] = df['Holiday/Promotion'].fillna(df['Holiday/Promotion'].mode()[0])
df['Seasonality'] = df['Seasonality'].fillna(df['Seasonality'].mode()[0])
df['Units Ordered'] = df['Units Ordered'].fillna(df['Demand Forecast'])
df['Units Ordered'] = df['Units Ordered'].fillna(df.groupby('Category')['Units Ordered'].transform('mean'))
df['Units Ordered'] = df['Units Ordered'].fillna(0)

# %% [markdown]
# ## Checking the missing values

# %%
df.isnull().sum()
# Out:
# Date                  0
# Store ID              0
# Product ID            0
# Category              0
# Region                0
# Inventory Level       0
# Units Sold            0
# Units Ordered         0
# Demand Forecast       0
# Price                 0
# Discount              0
# Weather Condition     0
# Holiday/Promotion     0
# Competitor Pricing    0
# Seasonality           0
# dtype: int64

# %%
df.head(10)
# Out:
#        Date Store ID Product ID     Category Region  Inventory Level  \
# 0  1/1/2022     S001      P0001    Groceries  North              231
# 1  1/1/2022     S001      P0002         Toys  South              204
# 2  1/1/2022     S001      P0003         Toys   West              102
# 3  1/1/2022     S001      P0004         Toys  North              469
# 4  1/1/2022     S001      P0005  Electronics   East              166
# 5  1/1/2022     S001      P0006    Groceries  South              138
# 6  1/1/2022     S001      P0007    Furniture   East              359
# 7  1/1/2022     S001      P0008     Clothing  North              380
# 8  1/1/2022     S001      P0009  Electronics   West              183
# 9  1/1/2022     S001      P0010         Toys  South              108
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127          55.00           135.47  33.50        20
# 1         150          66.00           144.04  63.01        20
# 2          65          51.00            74.02  27.99        10
# 3          61          62.18            62.18  32.72        10
# 4          14         135.00             9.26  73.64         0
# 5         128         102.00           139.82  76.83        10
# 6          97         167.00           108.92  34.16        10
# 7         312          54.00           329.73  97.99         5
# 8         175         135.00           174.15  20.74        10
# 9          28         196.00            24.47  59.99         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                0.0               29.69      Autumn
# 1             Sunny                0.0               66.16      Autumn
# 2             Sunny                1.0               31.32      Summer
# 3            Cloudy                1.0               34.74      Autumn
# 4             Sunny                0.0               68.95      Summer
# 5             Sunny                1.0               79.35      Winter
# 6             Rainy                1.0               36.55      Winter
# 7             Sunny                0.0              100.09      Spring
# 8            Cloudy                0.0               17.66      Autumn
# 9             Rainy                1.0               61.21      Winter

# %% [markdown]
# ## Navigating the total Units that have been sold during months

# %%
df['Month'] = df['Date'].dt.month
df['Month'] = df['Date'].dt.to_period('M')
#This line extracts the year-month period from each date and stores it in a new 'Month' column.
#This simplifies time-based analysis and makes it easier to group or summarize data by month.
df.groupby('Month')['Units Sold'].count()
# Out:
# Month
# 2022-01    3100
# 2022-02    2800
# 2022-03    3100
# 2022-04    3000
# 2022-05    3100
# 2022-06    3000
# 2022-07    3100
# 2022-08    3100
# 2022-09    3000
# 2022-10    3100
# 2022-11    3000
# 2022-12    3100
# 2023-01    3100
# 2023-02    2800
# 2023-03    3100
# 2023-04    3000
# 2023-05    3100
# 2023-06    3000
# 2023-07    3100
# 2023-08    3100
# 2023-09    3000
# 2023-10    3100
# 2023-11    3000
# 2023-12    3100
# 2024-01     100
# Freq: M, Name: Units Sold, dtype: int64

# %% [markdown]
# ## In this step, we identify and analyze the frequency of zero-sales cases across different months.
# ### This can help detect seasonal dips, stock issues, or product mismatch in specific periods.
# #### Sorting by month helps visualize this chronologically.

# %%
zero_sales = df[df['Units Sold'] == 0]
print(zero_sales['Month'].value_counts().sort_index())
# Out:
# Month
# 2022-01    12
# 2022-02    10
# 2022-03    14
# 2022-04    12
# 2022-05    15
# 2022-06    15
# 2022-07    21
# 2022-08    12
# 2022-09    16
# 2022-10    14
# 2022-11    10
# 2022-12    17
# 2023-01    15
# 2023-02    17
# 2023-03    21
# 2023-04    14
# 2023-05    14
# 2023-06    26
# 2023-07    18
# 2023-08    19
# 2023-09    15
# 2023-10     6
# 2023-11    12
# 2023-12    15
# Freq: M, Name: count, dtype: int64

# %% [markdown]
# #### In this step, we identify which products recorded zero units sold by counting how often each product appears in the filtered zero-sales data.

# %%
print(zero_sales['Product ID'].value_counts())
# Out:
# Product ID
# P0019    25
# P0004    24
# P0018    24
# P0015    24
# P0010    24
# P0020    20
# P0007    20
# P0014    20
# P0017    19
# P0001    18
# P0008    16
# P0016    16
# P0006    16
# P0013    16
# P0011    15
# P0002    15
# P0003    13
# P0012    13
# P0005    12
# P0009    10
# Name: count, dtype: int64

# %% [markdown]
# ## This step creates a comprehensive table that shows:
#
# ### The total occurrences of each Weather Condition for each month.
#
# ### The number of holidays (where Holiday/Promotion = 1) for each month.
#
# ## The table merges two groups:
#
# ### Weather counts: How often each weather condition occurs in each month.
#
# ### Holiday counts: The total number of holidays (sum of 1s for each month).
#
# #### Note: If Holiday/Promotion = 0, it’s treated as a normal working day.

# %%
# Group by Month and Weather Condition to count occurrences
weather_counts = zero_sales.groupby(['Month', 'Weather Condition']).size().reset_index(name='Weather Condition Count')

# Group by Month to count the number of holidays (Holiday/Promotion = 1)
holiday_counts = zero_sales.groupby('Month')['Holiday/Promotion'].sum().reset_index(name='Holiday Count')

# Merge the two dataframes on 'Month' to display both counts together
full_table = pd.merge(weather_counts, holiday_counts, on='Month', how='left')

# Display the resulting full table
import pandas as pd
pd.set_option('display.max_rows', None)  # Optional: To display all rows without truncation
display(full_table)
# Out:
#       Month Weather Condition  Weather Condition Count  Holiday Count
# 0   2022-01            Cloudy                        2            6.0
# 1   2022-01             Rainy                        2            6.0
# 2   2022-01             Snowy                        2            6.0
# 3   2022-01             Sunny                        6            6.0
# 4   2022-02            Cloudy                        1            5.0
# 5   2022-02             Rainy                        1            5.0
# 6   2022-02             Snowy                        4            5.0
# 7   2022-02             Sunny                        4            5.0
# 8   2022-03            Cloudy                        2            5.0
# 9   2022-03             Rainy                        3            5.0
# 10  2022-03             Snowy                        3            5.0
# 11  2022-03             Sunny                        6            5.0
# 12  2022-04            Cloudy                        7            5.0
# 13  2022-04             Rainy                        3            5.0
# 14  2022-04             Snowy                        2            5.0
# 15  2022-05            Cloudy                        5            5.0
# 16  2022-05             Rainy                        3            5.0
# 17  2022-05             Snowy                        4            5.0
# 18  2022-05             Sunny                        3            5.0
# 19  2022-06            Cloudy                        1            8.0
# 20  2022-06             Rainy                        6            8.0
# 21  2022-06             Snowy                        5            8.0
# 22  2022-06             Sunny                        3            8.0
# 23  2022-07            Cloudy                        7           10.0
# 24  2022-07             Rainy                        2           10.0
# 25  2022-07             Snowy                        9           10.0
# 26  2022-07             Sunny                        3           10.0
# 27  2022-08            Cloudy                        2            5.0
# 28  2022-08             Rainy                        3            5.0
# 29  2022-08             Snowy                        2            5.0
# 30  2022-08             Sunny                        5            5.0
# 31  2022-09            Cloudy                        3            7.0
# 32  2022-09             Rainy                        3            7.0
# 33  2022-09             Snowy                        5            7.0
# 34  2022-09             Sunny                        5            7.0
# 35  2022-10            Cloudy                        6            7.0
# 36  2022-10             Rainy                        4            7.0
# 37  2022-10             Snowy                        2            7.0
# 38  2022-10             Sunny                        2            7.0
# 39  2022-11            Cloudy                        2            4.0
# 40  2022-11             Rainy                        3            4.0
# 41  2022-11             Snowy                        1            4.0
# 42  2022-11             Sunny                        4            4.0
# 43  2022-12            Cloudy                        2            6.0
# 44  2022-12             Rainy                        5            6.0
# 45  2022-12             Snowy                        2            6.0
# 46  2022-12             Sunny                        8            6.0
# 47  2023-01            Cloudy                        2            9.0
# 48  2023-01             Rainy                        2            9.0
# 49  2023-01             Snowy                        5            9.0
# 50  2023-01             Sunny                        6            9.0
# 51  2023-02            Cloudy                        6            6.0
# 52  2023-02             Rainy                        8            6.0
# 53  2023-02             Snowy                        3            6.0
# 54  2023-03            Cloudy                        8            9.0
# 55  2023-03             Rainy                        2            9.0
# 56  2023-03             Snowy                        8            9.0
# 57  2023-03             Sunny                        3            9.0
# 58  2023-04            Cloudy                        2            7.0
# 59  2023-04             Rainy                        2            7.0
# 60  2023-04             Snowy                        6            7.0
# 61  2023-04             Sunny                        4            7.0
# 62  2023-05            Cloudy                        2            4.0
# 63  2023-05             Rainy                        5            4.0
# 64  2023-05             Snowy                        3            4.0
# 65  2023-05             Sunny                        4            4.0
# 66  2023-06            Cloudy                        6           10.0
# 67  2023-06             Rainy                        3           10.0
# 68  2023-06             Snowy                        7           10.0
# 69  2023-06             Sunny                       10           10.0
# 70  2023-07            Cloudy                        4           10.0
# 71  2023-07             Rainy                        3           10.0
# 72  2023-07             Snowy                        6           10.0
# 73  2023-07             Sunny                        5           10.0
# 74  2023-08            Cloudy                        3           11.0
# 75  2023-08             Rainy                        6           11.0
# 76  2023-08             Snowy                        3           11.0
# 77  2023-08             Sunny                        7           11.0
# 78  2023-09            Cloudy                        4            6.0
# 79  2023-09             Rainy                        2            6.0
# 80  2023-09             Snowy                        4            6.0
# 81  2023-09             Sunny                        5            6.0
# 82  2023-10            Cloudy                        2            2.0
# 83  2023-10             Rainy                        1            2.0
# 84  2023-10             Sunny                        3            2.0
# 85  2023-11            Cloudy                        2            7.0
# 86  2023-11             Rainy                        6            7.0
# 87  2023-11             Snowy                        2            7.0
# 88  2023-11             Sunny                        2            7.0
# 89  2023-12            Cloudy                        4            4.0
# 90  2023-12             Rainy                        1            4.0
# 91  2023-12             Snowy                        6            4.0
# 92  2023-12             Sunny                        4            4.0

# %%
df.head(10)
# Out:
#         Date Store ID Product ID     Category Region  Inventory Level  \
# 0 2022-01-01     S001      P0001    Groceries  North              231
# 1 2022-01-01     S001      P0002         Toys  South              204
# 2 2022-01-01     S001      P0003         Toys   West              102
# 3 2022-01-01     S001      P0004         Toys  North              469
# 4 2022-01-01     S001      P0005  Electronics   East              166
# 5 2022-01-01     S001      P0006    Groceries  South              138
# 6 2022-01-01     S001      P0007    Furniture   East              359
# 7 2022-01-01     S001      P0008     Clothing  North              380
# 8 2022-01-01     S001      P0009  Electronics   West              183
# 9 2022-01-01     S001      P0010         Toys  South              108
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127          55.00           135.47  33.50        20
# 1         150          66.00           144.04  63.01        20
# 2          65          51.00            74.02  27.99        10
# 3          61          62.18            62.18  32.72        10
# 4          14         135.00             9.26  73.64         0
# 5         128         102.00           139.82  76.83        10
# 6          97         167.00           108.92  34.16        10
# 7         312          54.00           329.73  97.99         5
# 8         175         135.00           174.15  20.74        10
# 9          28         196.00            24.47  59.99         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality  \
# 0             Rainy                0.0               29.69      Autumn
# 1             Sunny                0.0               66.16      Autumn
# 2             Sunny                1.0               31.32      Summer
# 3            Cloudy                1.0               34.74      Autumn
# 4             Sunny                0.0               68.95      Summer
# 5             Sunny                1.0               79.35      Winter
# 6             Rainy                1.0               36.55      Winter
# 7             Sunny                0.0              100.09      Spring
# 8            Cloudy                0.0               17.66      Autumn
# 9             Rainy                1.0               61.21      Winter
#
#      Month
# 0  2022-01
# 1  2022-01
# 2  2022-01
# 3  2022-01
# 4  2022-01
# 5  2022-01
# 6  2022-01
# 7  2022-01
# 8  2022-01
# 9  2022-01

# %%
print("Cleaned dataset saved as 'CleanedDataSet.csv'")
# Out:
# Cleaned dataset saved as 'CleanedDataSet.csv'
