# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in d:\download\anaconda\lib\site-packages (2.22.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in d:\download\anaconda\lib\site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: Flask<4 in d:\download\anaconda\lib\site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: Jinja2<4,>=3.0 in d:\download\anaconda\lib\site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in d:\download\anaconda\lib\site-packages (from mlflow) (1.13.3)
# Requirement already satisfied: docker<8,>=4.0.0 in d:\download\anaconda\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in d:\download\anaconda\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in d:\download\anaconda\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in d:\download\anaconda\lib\site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: numpy<3 in d:\download\anaconda\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in d:\download\anaconda\lib\site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in d:\download\anaconda\lib\site-packages (from mlflow) (16.1.0)
# Requirement already satisfied: scikit-learn<2 in d:\download\anaconda\lib\site-packages (from mlflow) (1.5.1)
# Requirement already satisfied: scipy<2 in d:\download\anaconda\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in d:\download\anaconda\lib\site-packages (from mlflow) (2.0.34)
# Requirement already satisfied: waitress<4 in d:\download\anaconda\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.52.0)
# Requirement already satisfied: fastapi<1 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (7.0.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (1.32.1)
# Requirement already satisfied: packaging<25 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (24.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (4.25.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (2.8.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Requirement already satisfied: uvicorn<1 in d:\download\anaconda\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.34.2)
# Requirement already satisfied: Mako in d:\download\anaconda\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.3)
# Requirement already satisfied: pywin32>=304 in d:\download\anaconda\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: urllib3>=1.26.0 in d:\download\anaconda\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.2.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in d:\download\anaconda\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\download\anaconda\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in d:\download\anaconda\lib\site-packages (from Flask<4->mlflow) (1.6.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in d:\download\anaconda\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in d:\download\anaconda\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in d:\download\anaconda\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\download\anaconda\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\download\anaconda\lib\site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\download\anaconda\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\download\anaconda\lib\site-packages (from matplotlib<4->mlflow) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\download\anaconda\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=8 in d:\download\anaconda\lib\site-packages (from matplotlib<4->mlflow) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\download\anaconda\lib\site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in d:\download\anaconda\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\download\anaconda\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\download\anaconda\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\download\anaconda\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\download\anaconda\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.1)
# Requirement already satisfied: colorama in d:\download\anaconda\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.22.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in d:\download\anaconda\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (2.40.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in d:\download\anaconda\lib\site-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\download\anaconda\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in d:\download\anaconda\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.17.0)
# Requirement already satisfied: deprecated>=1.2.6 in d:\download\anaconda\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in d:\download\anaconda\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.53b1)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\download\anaconda\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\download\anaconda\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.20.1)
# Requirement already satisfied: six>=1.5 in d:\download\anaconda\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\download\anaconda\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\download\anaconda\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\download\anaconda\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in d:\download\anaconda\lib\site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.14.0)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\download\anaconda\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.14.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in d:\download\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\download\anaconda\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\download\anaconda\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\download\anaconda\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in d:\download\anaconda\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\download\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.4.8)

# %%
import pandas as pd
import pickle
import mlflow
import mlflow.sklearn
import mlflow.xgboost
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder

# %%
df_ml=pd.read_csv("CleanedDataSet.csv")

# %%
df_ml['Date'] = pd.to_datetime(df_ml['Date'])
df_ml['Month'] = df_ml['Date'].dt.to_period('M').astype(str)

# %%
df_ml['Profit'] = (df_ml['Price'] * (1 - df_ml['Discount'] / 100)) * df_ml['Units Sold']

df_ml['Year'] = df_ml['Date'].dt.year
df_ml['Month_Num'] = df_ml['Date'].dt.month
df_ml['Day'] = df_ml['Date'].dt.day
df_ml['DayOfWeek'] = df_ml['Date'].dt.dayofweek
df_ml['DayOfYear'] = df_ml['Date'].dt.dayofyear
df_ml['WeekOfYear'] = df_ml['Date'].dt.isocalendar().week.astype(int)
df_ml['Quarter'] = df_ml['Date'].dt.quarter

# Handle missing values
df_ml.fillna(0, inplace=True)

# %%
targets = ['Units Sold', 'Profit']
features = [col for col in df_ml.columns if col not in targets + ['Date', 'Month']]
categorical_features = ['Category', 'Region', 'Weather Condition', 'Holiday/Promotion', 'Year', 'Month_Num', 'DayOfWeek', 'Quarter']
numerical_features = [col for col in features if col not in categorical_features and df_ml[col].dtype in ['int64', 'float64']]

# One-hot encode categorical features
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_cats = encoder.fit_transform(df_ml[categorical_features])
encoded_cat_df = pd.DataFrame(encoded_cats, columns=encoder.get_feature_names_out(categorical_features))

# Create processed DataFrame
df_processed = pd.concat([df_ml[numerical_features], encoded_cat_df, df_ml[targets]], axis=1)
df_processed['Date'] = df_ml['Date']

# Sort by date
df_processed = df_processed.sort_values('Date')

# %%
split_index = int(len(df_processed) * 0.8)
train_df = df_processed.iloc[:split_index]
test_df = df_processed.iloc[split_index:]

X_train = train_df.drop(targets + ['Date'], axis=1)
y_train_units = train_df['Units Sold']
y_train_profit = train_df['Profit']
X_test = test_df.drop(targets + ['Date'], axis=1)
y_test_units = test_df['Units Sold']
y_test_profit = test_df['Profit']
test_dates = test_df['Date']

# %%
import pandas as pd
import pickle
import mlflow
import mlflow.sklearn
import mlflow.xgboost
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score

# === Load models ===
with open("xgb_units_model.pkl", "rb") as f:
    units_model = pickle.load(f)

with open("xgb_profit_model.pkl", "rb") as f:
    profit_model = pickle.load(f)

mlflow.set_tracking_uri("http://127.0.0.1:5000")
# 3.2 Set the experiment name (will create one if it doesn't exist)
mlflow.set_experiment("Retail store")
# === Get feature names from models
trained_features = units_model.get_booster().feature_names if hasattr(units_model, "get_booster") else units_model.feature_names_in_

# === Align test data columns to match training features
X_test = X_test[trained_features]

# === Get feature names from models
trained_features = units_model.get_booster().feature_names if hasattr(units_model, "get_booster") else units_model.feature_names_in_

# === Align test data columns to match training features
X_test = X_test[trained_features]

# === Logging function ===
def log_model_with_metrics(model, model_name, X, y_true):
    y_pred = model.predict(X)

    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)

    with mlflow.start_run(run_name=f"{model_name}_run"):
        mlflow.log_param("model_name", model_name)
        mlflow.log_metric("R2_score", r2)
        mlflow.log_metric("MSE", mse)

        # Log the model
        if isinstance(model, xgb.Booster):
            mlflow.xgboost.log_model(model, "model")
        elif "sklearn" in str(type(model)).lower():
            mlflow.sklearn.log_model(model, "model")
        else:
            raise TypeError(f"Unsupported model type: {type(model)}")

        print(f"✅ {model_name} logged with R²={r2:.3f}, MSE={mse:.3f}")

# === Log both models
log_model_with_metrics(units_model, "units_model", X_test, y_test_units)
log_model_with_metrics(profit_model, "profit_model", X_test, y_test_profit)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#
# File d:\Download\Anaconda\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File d:\Download\Anaconda\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File d:\Download\Anaconda\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connection.py:214, in HTTPConnection._new_conn(self)
#     213 except OSError as e:
# --> 214     raise NewConnectionError(
#     215         self, f"Failed to establish a new connection: {e}"
#     216     ) from e
#     218 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001CA75797800>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File d:\Download\Anaconda\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 873 (4 times)]
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File d:\Download\Anaconda\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=Retail+store (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001CA75797800>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File d:\Download\Anaconda\Lib\site-packages\mlflow\utils\rest_utils.py:184, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     183 try:
# --> 184     return _get_http_response_with_retries(
#     185         method,
#     186         url,
#     187         max_retries,
#     188         backoff_factor,
#     189         backoff_jitter,
#     190         retry_codes,
#     191         raise_on_status,
#     192         headers=headers,
#     193         verify=host_creds.verify,
#     194         timeout=timeout,
#     195         respect_retry_after_header=respect_retry_after_header,
#     196         **kwargs,
#     197     )
#     198 except requests.exceptions.Timeout as to:
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File d:\Download\Anaconda\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\Download\Anaconda\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File d:\Download\Anaconda\Lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=Retail+store (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001CA75797800>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[9], line 18
#      16 mlflow.set_tracking_uri("http://127.0.0.1:5000")
#      17 # 3.2 Set the experiment name (will create one if it doesn't exist)
# ---> 18 mlflow.set_experiment("Retail store")
#      19 # === Get feature names from models
#      20 trained_features = units_model.get_booster().feature_names if hasattr(units_model, "get_booster") else units_model.feature_names_in_
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\tracking\fluent.py:157, in set_experiment(experiment_name, experiment_id)
#     155 with _experiment_lock:
#     156     if experiment_id is None:
# --> 157         experiment = client.get_experiment_by_name(experiment_name)
#     158         if not experiment:
#     159             try:
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\tracking\client.py:1703, in MlflowClient.get_experiment_by_name(self, name)
#    1671 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1672     """Retrieve an experiment by experiment name from the backend store
#    1673
#    1674     Args:
#    (...)
#    1701         Lifecycle_stage: active
#    1702     """
# -> 1703     return self._tracking_client.get_experiment_by_name(name)
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:591, in TrackingServiceClient.get_experiment_by_name(self, name)
#     583 def get_experiment_by_name(self, name):
#     584     """
#     585     Args:
#     586         name: The experiment name.
#    (...)
#     589         :py:class:`mlflow.entities.Experiment`
#     590     """
# --> 591     return self.store.get_experiment_by_name(name)
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\store\tracking\rest_store.py:641, in RestStore.get_experiment_by_name(self, experiment_name)
#     639 try:
#     640     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 641     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     642     return Experiment.from_proto(response_proto.experiment)
#     643 except MlflowException as e:
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\store\tracking\rest_store.py:90, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      88     endpoint, method = _METHOD_TO_INFO[api]
#      89 response_proto = api.Response()
# ---> 90 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\utils\rest_utils.py:397, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     395 if method == "GET":
#     396     call_kwargs["params"] = json_body
# --> 397     response = http_request(**call_kwargs)
#     398 else:
#     399     call_kwargs["json"] = json_body
#
# File d:\Download\Anaconda\Lib\site-packages\mlflow\utils\rest_utils.py:207, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     205     raise InvalidUrlException(f"Invalid url: {url}") from iu
#     206 except Exception as e:
# --> 207     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to http://127.0.0.1:5000/api/2.0/mlflow/experiments/get-by-name failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=Retail+store (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001CA75797800>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
